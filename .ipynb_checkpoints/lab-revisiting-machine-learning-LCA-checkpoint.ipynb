# %%
import pandas as pd

# %%
df = pd.read_csv('learningSet.csv')
# Out:
# /var/folders/v4/bqj9vzp11vd1cvhf93rmpqt00000gp/T/ipykernel_33555/1786901675.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('learningSet.csv')

# %%
df.head(5)
# Out:
#    ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH
# 0     8901     GRI      0    IL  61081                    3712      0  \
# 1     9401     BOA      1    CA  91326                    5202      0
# 2     9001     AMH      1    NC  27017                       0      0
# 3     8701     BRY      0    CA  95953                    2801      0
# 4     8601              0    FL  33176                    2001      0
#
#   RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F
# 0           ...      0.0        0      L      4      E        X         X  \
# 1           ...      0.0        0      L      2      G        X         X
# 2           ...      0.0        1      L      4      E        X         X
# 3           ...      0.0        1      L      4      E        X         X
# 4        X  ...      0.0        1      L      2      F        X         X
#
#   MDMAUD_A CLUSTER2 GEOCODE2
# 0        X     39.0        C
# 1        X      1.0        A
# ...

# %% [markdown]
# Check for null values in all the columns

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# RDATE_5    95403
# RAMNT_5    95403
# RDATE_3    95170
# RAMNT_3    95170
# RDATE_4    95131
#            ...
# ETHC3          0
# ETHC2          0
# ETHC1          0
# HHD12          0
# TPE11          0
# Length: 481, dtype: int64

# %%
for column in df.columns:
    count = df[column].isnull().sum()
    print(f'{column}: {count}')
# Out:
# ODATEDW: 0
# OSOURCE: 0
# TCODE: 0
# STATE: 0
# ZIP: 0
# MAILCODE: 0
# PVASTATE: 0
# DOB: 0
# NOEXCH: 0
# RECINHSE: 0
# RECP3: 0
# RECPGVG: 0
# RECSWEEP: 0
# MDMAUD: 0
# DOMAIN: 0
# CLUSTER: 0
# AGE: 23665
# AGEFLAG: 0
# HOMEOWNR: 0
# CHILD03: 0
# CHILD07: 0
# CHILD12: 0
# CHILD18: 0
# NUMCHLD: 83026
# INCOME: 21286
# GENDER: 0
# WEALTH1: 44732
# HIT: 0
# MBCRAFT: 52854
# MBGARDEN: 52854
# MBBOOKS: 52854
# MBCOLECT: 52914
# MAGFAML: 52854
# MAGFEM: 52854
# MAGMALE: 52854
# PUBGARDN: 52854
# PUBCULIN: 52854
# PUBHLTH: 52854
# PUBDOITY: 52854
# PUBNEWFN: 52854
# PUBPHOTO: 52854
# PUBOPP: 52854
# DATASRCE: 0
# MALEMILI: 0
# MALEVET: 0
# VIETVETS: 0
# WWIIVETS: 0
# LOCALGOV: 0
# STATEGOV: 0
# FEDGOV: 0
# SOLP3: 0
# SOLIH: 0
# MAJOR: 0
# WEALTH2: 43823
# GEOCODE: 0
# COLLECT1: 0
# VETERANS: 0
# BIBLE: 0
# CATLG: 0
# HOMEE: 0
# PETS: 0
# CDPLAY: 0
# STEREO: 0
# PCOWNERS: 0
# PHOTO: 0
# CRAFTS: 0
# FISHER: 0
# GARDENIN: 0
# BOATS: 0
# WALKER: 0
# KIDSTUFF: 0
# CARDS: 0
# PLATES: 0
# ...

# %% [markdown]
# Exclude the following variables by looking at the definitions.

# %%
drop_list = []

# %%
drop_list.append('OSOURCE')

# %%
drop_list.append('ZIP')

# %%
drop_list
# Out:
# ['OSOURCE', 'ZIP']

# %%
df.drop(columns = drop_list, inplace = True)

# %% [markdown]
# Identify columns that over 85% missing values

# %%
for column in df.columns:
    percentage = df[column].isnull().mean()
    print(f'{column}: {round(percentage*100, 2)}%')
# Out:
# ODATEDW: 0.0%
# TCODE: 0.0%
# STATE: 0.0%
# MAILCODE: 0.0%
# PVASTATE: 0.0%
# DOB: 0.0%
# NOEXCH: 0.0%
# RECINHSE: 0.0%
# RECP3: 0.0%
# RECPGVG: 0.0%
# RECSWEEP: 0.0%
# MDMAUD: 0.0%
# DOMAIN: 0.0%
# CLUSTER: 0.0%
# AGE: 24.8%
# AGEFLAG: 0.0%
# HOMEOWNR: 0.0%
# CHILD03: 0.0%
# CHILD07: 0.0%
# CHILD12: 0.0%
# CHILD18: 0.0%
# NUMCHLD: 87.02%
# INCOME: 22.31%
# GENDER: 0.0%
# WEALTH1: 46.88%
# HIT: 0.0%
# MBCRAFT: 55.4%
# MBGARDEN: 55.4%
# MBBOOKS: 55.4%
# MBCOLECT: 55.46%
# MAGFAML: 55.4%
# MAGFEM: 55.4%
# MAGMALE: 55.4%
# PUBGARDN: 55.4%
# PUBCULIN: 55.4%
# PUBHLTH: 55.4%
# PUBDOITY: 55.4%
# PUBNEWFN: 55.4%
# PUBPHOTO: 55.4%
# PUBOPP: 55.4%
# DATASRCE: 0.0%
# MALEMILI: 0.0%
# MALEVET: 0.0%
# VIETVETS: 0.0%
# WWIIVETS: 0.0%
# LOCALGOV: 0.0%
# STATEGOV: 0.0%
# FEDGOV: 0.0%
# SOLP3: 0.0%
# SOLIH: 0.0%
# MAJOR: 0.0%
# WEALTH2: 45.93%
# GEOCODE: 0.0%
# COLLECT1: 0.0%
# VETERANS: 0.0%
# BIBLE: 0.0%
# CATLG: 0.0%
# HOMEE: 0.0%
# PETS: 0.0%
# CDPLAY: 0.0%
# STEREO: 0.0%
# PCOWNERS: 0.0%
# ...

# %% [markdown]
# Remove those columns from the dataframe

# %%
column_to_drop = []

# %%
for column in df.columns:
    percentage = df[column].isnull().mean()
    if percentage > .85:
        column_to_drop.append(column)

column_to_drop
# Out:
# ['NUMCHLD',
#  'RDATE_3',
#  'RDATE_4',
#  'RDATE_5',
#  'RDATE_6',
#  'RDATE_7',
#  'RDATE_10',
#  'RDATE_13',
#  'RDATE_15',
#  'RDATE_17',
#  'RDATE_20',
#  'RDATE_21',
#  'RDATE_23',
#  'RAMNT_3',
#  'RAMNT_4',
#  'RAMNT_5',
#  'RAMNT_6',
#  'RAMNT_7',
#  'RAMNT_10',
#  'RAMNT_13',
#  'RAMNT_15',
#  'RAMNT_17',
#  'RAMNT_20',
#  'RAMNT_21',
#  'RAMNT_23']

# %%
df.drop(columns = column_to_drop, inplace = True)

# %% [markdown]
# Reduce the number of categories in the column GENDER.
# The column should only have either "M" for males, "F" for females, and
# "other" for all the rest

# %%
df['GENDER'].value_counts()
# Out:
# GENDER
# F    51277
# M    39094
#       2957
# U     1715
# J      365
# C        2
# A        2
# Name: count, dtype: int64

# %%
df['GENDER'] = df['GENDER'].fillna('F')

# %%
df['GENDER'].isna().sum()
# Out:
# 0

# %%
for i in df.GENDER:
    if i == ' ':
        df.GENDER.replace(' ','F', inplace = True)
    elif i == 'U':
        df.GENDER.replace('U','other', inplace = True)
    elif i == 'J':
        df.GENDER.replace('J','other', inplace = True)
    elif i == 'C':
        df.GENDER.replace('C','other', inplace = True)
    elif i == 'A':
        df.GENDER.replace('A','other', inplace = True)

# %%
df['GENDER'].value_counts()
# Out:
# GENDER
# F        54234
# M        39094
# other     2084
# Name: count, dtype: int64
